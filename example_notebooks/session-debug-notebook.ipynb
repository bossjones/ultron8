# %%
import requests
import ultron8
from ultron8 import debugger
from ultron8 import client
from ultron8.api import settings
from ultron8.u8client import session

username = settings.FIRST_SUPERUSER
password = settings.FIRST_SUPERUSER_PASSWORD

# %%
s = session.BasicAuth(username, password)

# %%
debugger.debug_dump_exclude(s)
# Out:
# obj.__call__ = <bound method HTTPBasicAuth.__call__ of basic admin@ultron8.com>
# obj.__class__ = <class 'ultron8.u8client.session.BasicAuth'>
# obj.__delattr__ = <method-wrapper '__delattr__' of BasicAuth object at 0x10cd8e050>
# obj.__dict__ = {'username': 'admin@ultron8.com', 'password': 'password'}
# obj.__dir__ = <built-in method __dir__ of BasicAuth object at 0x10cd8e050>
# obj.__eq__ = <bound method HTTPBasicAuth.__eq__ of basic admin@ultron8.com>
# obj.__format__ = <built-in method __format__ of BasicAuth object at 0x10cd8e050>
# obj.__ge__ = <method-wrapper '__ge__' of BasicAuth object at 0x10cd8e050>
# obj.__getattribute__ = <method-wrapper '__getattribute__' of BasicAuth object at 0x10cd8e050>
# obj.__gt__ = <method-wrapper '__gt__' of BasicAuth object at 0x10cd8e050>
# obj.__hash__ = None
# obj.__init__ = <bound method HTTPBasicAuth.__init__ of basic admin@ultron8.com>
# obj.__init_subclass__ = <built-in method __init_subclass__ of type object at 0x7f8f9888b2c0>
# obj.__le__ = <method-wrapper '__le__' of BasicAuth object at 0x10cd8e050>
# obj.__lt__ = <method-wrapper '__lt__' of BasicAuth object at 0x10cd8e050>
# obj.__module__ = ultron8.u8client.session
# obj.__ne__ = <bound method HTTPBasicAuth.__ne__ of basic admin@ultron8.com>
# obj.__new__ = <built-in method __new__ of type object at 0x1099e3aa0>
# obj.__reduce__ = <built-in method __reduce__ of BasicAuth object at 0x10cd8e050>
# obj.__reduce_ex__ = <built-in method __reduce_ex__ of BasicAuth object at 0x10cd8e050>
# obj.__repr__ = <bound method BasicAuth.__repr__ of basic admin@ultron8.com>
# obj.__setattr__ = <method-wrapper '__setattr__' of BasicAuth object at 0x10cd8e050>
# obj.__sizeof__ = <built-in method __sizeof__ of BasicAuth object at 0x10cd8e050>
# obj.__str__ = <method-wrapper '__str__' of BasicAuth object at 0x10cd8e050>
# obj.__subclasshook__ = <built-in method __subclasshook__ of type object at 0x7f8f9888b2c0>
# obj.__weakref__ = None
# obj.password = password
# obj.username = admin@ultron8.com

# %%
debugger.dump_magic(s)
# Out:
# obj.password = password
# obj.username = admin@ultron8.com

# %%
debugger.dump_all(s)
# Out:
# [run]--------------[dir(obj)]--------------
# dump_dir for object: basic admin@ultron8.com
# [   '__call__',
#     '__class__',
#     '__delattr__',
#     '__dict__',
#     '__dir__',
#     '__doc__',
#     '__eq__',
#     '__format__',
#     '__ge__',
#     '__getattribute__',
#     '__gt__',
#     '__hash__',
#     '__init__',
#     '__init_subclass__',
#     '__le__',
#     '__lt__',
#     '__module__',
#     '__ne__',
#     '__new__',
#     '__reduce__',
#     '__reduce_ex__',
#     '__repr__',
#     '__setattr__',
#     '__sizeof__',
#     '__str__',
#     '__subclasshook__',
#     '__weakref__',
#     'password',
#     'username']
# [run]--------------[obj.__dict__]--------------
# dump_dict for object: basic admin@ultron8.com
# {'password': 'password', 'username': 'admin@ultron8.com'}
# [run]--------------[pp.pprint(vars(obj))]--------------
# dump_vars for object: basic admin@ultron8.com
# {'password': 'password', 'username': 'admin@ultron8.com'}

# %%
assert isinstance(s, ultron8.u8client.session.BasicAuth)

# %%
url = "http://localhost:11267/v1/users"

r = requests.Request('GET', url, auth=s)
p = r.prepare()

assert isinstance(s, ultron8.u8client.session.BasicAuth)
assert s.password == "password"
assert s.username == "admin@ultron8.com"

assert p.headers['Authorization'] == requests.auth._basic_auth_str(username, password)

# %%
p
# Out:
# <PreparedRequest [GET]>

# %%
debugger.dump_all(p)
# Out:
# [run]--------------[dir(obj)]--------------
# dump_dir for object: <PreparedRequest [GET]>
# [   '__class__',
#     '__delattr__',
#     '__dict__',
#     '__dir__',
#     '__doc__',
#     '__eq__',
#     '__format__',
#     '__ge__',
#     '__getattribute__',
#     '__gt__',
#     '__hash__',
#     '__init__',
#     '__init_subclass__',
#     '__le__',
#     '__lt__',
#     '__module__',
#     '__ne__',
#     '__new__',
#     '__reduce__',
#     '__reduce_ex__',
#     '__repr__',
#     '__setattr__',
#     '__sizeof__',
#     '__str__',
#     '__subclasshook__',
#     '__weakref__',
#     '_body_position',
#     '_cookies',
#     '_encode_files',
#     '_encode_params',
#     '_get_idna_encoded_host',
#     'body',
#     'copy',
#     'deregister_hook',
#     'headers',
#     'hooks',
#     'method',
#     'path_url',
#     'prepare',
#     'prepare_auth',
#     'prepare_body',
#     'prepare_content_length',
#     'prepare_cookies',
#     'prepare_headers',
#     'prepare_hooks',
#     'prepare_method',
#     'prepare_url',
#     'register_hook',
#     'url']
# [run]--------------[obj.__dict__]--------------
# dump_dict for object: <PreparedRequest [GET]>
# {   '_body_position': None,
#     '_cookies': <RequestsCookieJar[]>,
#     'body': None,
#     'headers': {'Authorization': 'Basic YWRtaW5AdWx0cm9uOC5jb206cGFzc3dvcmQ='},
#     'hooks': {'response': []},
#     'method': 'GET',
#     'url': 'http://localhost:11267/v1/users'}
# [run]--------------[pp.pprint(vars(obj))]--------------
# dump_vars for object: <PreparedRequest [GET]>
# {   '_body_position': None,
#     '_cookies': <RequestsCookieJar[]>,
#     'body': None,
#     'headers': {'Authorization': 'Basic YWRtaW5AdWx0cm9uOC5jb206cGFzc3dvcmQ='},
#     'hooks': {'response': []},
#     'method': 'GET',
#     'url': 'http://localhost:11267/v1/users'}

# %%
from tests.utils.utils import get_superuser_jwt_request

# %%
r = get_superuser_jwt_request()

# %%
r.json()
# Out:
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoxLCJleHAiOjE1ODk5Mjc1ODksInN1YiI6ImFjY2VzcyJ9.6WTl-IRDsAV1XymVx-caGQ42g_ZCC_aoMWGFgzN5IoI',
#  'token_type': 'bearer'}
